# %%
import mintapi

# %%
mint = mintapi.Mint(
    'joe83830@gmail.com',  # Email used to log in to Mint
    'Joe89623@CT',  # Your password used to log in to mint
    # Optional parameters
    mfa_method='sms',  # Can be 'sms' (default) or 'email'.
                       # if mintapi detects an MFA request, it will trigger the requested method
                       # and prompt on the command line.
    headless=False,  # Whether the chromedriver should work without opening a
                     # visible window (useful for server-side deployments)
    mfa_input_callback=None,  # A callback accepting a single argument (the prompt)
                              # which returns the user-inputted 2FA code. By default
                              # the default Python `input` function is used.
    session_path=None, # Directory that the Chrome persistent session will be written/read from.
                       # To avoid the 2FA code being asked for multiple times, you can either set
                       # this parameter or log in by hand in Chrome under the same user this runs
                       # as.
    imap_account=None, # account name used to log in to your IMAP server
    imap_password=None, # account password used to log in to your IMAP server
    imap_server=None,  # IMAP server host name
    imap_folder='INBOX',  # IMAP folder that receives MFA email
  )

# %%
overview = mint.get_accounts()

# %%
overview[1]
# Out:
# {'linkedAccountId': None,
#  'accountName': 'Bank of America Cash Rewards World Mastercard Card',
#  'addAccountDate': 1554843748000,
#  'fiLoginDisplayName': 'Bank of America',
#  'ccAggrStatus': 0,
#  'dueDate': '04/20/2019',
#  'exclusionType': '0',
#  'linkedAccount': None,
#  'isHiddenFromPlanningTrends': True,
#  'isTerminal': True,
#  'linkCreationTime': None,
#  'isActive': True,
#  'accountStatus': '1',
#  'accountSystemStatus': 'ACTIVE',
#  'lastUpdated': 1555029574000,
#  'fiLastUpdated': 1555029574000,
#  'yodleeAccountNumberLast4': '6861',
#  'isError': False,
#  'fiName': 'Bank of America',
#  'isAccountNotFound': False,
#  'klass': 'credit',
#  'possibleLinkAccounts': [],
#  'lastUpdatedInString': '18 seconds',
#  'accountTypeInt': 3,
#  'currency': 'USD',
#  'id': 10333543,
#  'isHostAccount': False,
#  'value': -539.18,
#  'fiLoginId': 4969958,
#  'usageType': None,
#  'interestRate': None,
#  'accountType': 'credit',
#  'currentBalance': 539.18,
#  'fiLoginStatus': 'OK',
#  'isAccountClosedByMint': False,
#  'userName': None,
#  'yodleeName': 'Bank of America Cash Rewards World Mastercard Card',
#  'closeDate': 1555029572000,
#  'linkStatus': 'NOT_LINKED',
#  'dueAmt': 359.43,
#  'accountId': 10333543,
#  'isClosed': False,
#  'fiLoginUIStatus': 'OK',
#  'yodleeAccountId': 75406744741,
#  'name': 'Bank of America Cash Rewards World Mastercard Card',
#  'status': '1',
#  'addAccountDateInDate': datetime.datetime(2019, 4, 9, 17, 2, 28),
#  'closeDateInDate': datetime.datetime(2019, 4, 11, 20, 39, 32),
#  'fiLastUpdatedInDate': datetime.datetime(2019, 4, 11, 20, 39, 34),
#  'lastUpdatedInDate': datetime.datetime(2019, 4, 11, 20, 39, 34)}

# %%
trans = mint.get_transactions()

# %%
bud = mint.get_budgets()

# %%
bud['spend'][3]
# Out:
# {'st': 2,
#  'ramt': 0,
#  'isIncome': False,
#  'isTransfer': False,
#  'isExpense': True,
#  'amt': 19.38,
#  'pid': 7,
#  'type': 0,
#  'bgt': 20.0,
#  'rbal': 0.62,
#  'ex': False,
#  'cat': 'Coffee Shops',
#  'id': 122849821,
#  'catTypeFilter': 'Personal'}

# %%
all_cat = set()
coffee_sum = 0
coffee_idx = []
coffee_brk = []

# %%
for i in range(trans.shape[0]):
    all_cat.add(trans.iloc[i][5])
    if trans.iloc[i]['category'] == 'restaurants':
        coffee_sum += trans.iloc[i]['amount']
        coffee_idx.append(i)
        coffee_brk.append(trans.iloc[i]['amount'])

# %%
all_cat
# Out:
# {'air travel',
#  'alcohol & bars',
#  'atm fee',
#  'business services',
#  'cash & atm',
#  'charity',
#  'check',
#  'coffee shops',
#  'credit card payment',
#  'electronics & software',
#  'eyecare',
#  'fast food',
#  'federal tax',
#  'fees & charges',
#  'financial advisor',
#  'food & dining',
#  'gas & fuel',
#  'gift',
#  'groceries',
#  'hair',
#  'health insurance',
#  'hotel',
#  'income',
#  'interest income',
#  'laundry',
#  'mortgage & rent',
#  'movies & dvds',
#  'music',
#  nan,
#  'newspapers & magazines',
#  'pharmacy',
#  'public transportation',
#  'rental car & taxi',
#  'restaurants',
#  'service fee',
#  'shipping',
#  'shopping',
#  'transfer',
#  'travel',
#  'vacation'}

# %%
trans
# Out:
#           date                                        description  \
# 0   2019-04-11                                          Wisalkhan
# 1   2019-04-11                                                MTA
# 2   2019-04-11                                              Tidal
# 3   2019-04-11                           Griffis Faculty Club Inc
# 4   2019-04-11                                        Hold Online
# 5   2019-04-11                                            Spotify
# 6   2019-04-11                                Deserve Entry Descr
# 7   2019-04-11                                        Mgp Chr Ono
# 8   2019-04-10                                     Deserve Web Id
# 9   2019-04-10                                Robinhood Funds Ppd
# 10  2019-04-10                                Robinhood Funds Ppd
# 11  2019-04-10                                Robinhood Funds Ppd
# 12  2019-04-10                                Robinhood Funds Ppd
# 13  2019-04-10                        Transfer from CHASE SAVINGS
# 14  2019-04-10                          Transfer to CHASE COLLEGE
# 15  2019-04-09                                            GrubHub
# 16  2019-04-09                        Transfer from CHASE SAVINGS
# 17  2019-04-09                          Transfer to CHASE COLLEGE
# 18  2019-04-08                                       Nyc Ferry Ny
# 19  2019-04-08                                            GrubHub
# 20  2019-04-08                                            GrubHub
# 21  2019-04-08                                                AMC
# 22  2019-04-08                                               Lyft
# 23  2019-04-08                                               Lyft
# 24  2019-04-06                                    Romano Grill Ls
# 25  2019-04-06                                Sommerfest Restaura
# 26  2019-04-06                                   Germany Bierline
# 27  2019-04-06                                  Liberty Inn Kiosk
# 28  2019-04-06                                       Plaza De Los
# 29  2019-04-06                                              Delta
# ..         ...                                                ...
# 322 2019-02-08                                       Cornell Tech
# 323 2019-02-08                                            GrubHub
# 324 2019-02-07                                          Fuji East
# 325 2019-02-07                                          Gristedes
# 326 2019-02-06                      Transfer from Rewards Savings
# 327 2019-02-06                                       Cornell Tech
# 328 2019-02-06                                              Aetna
# 329 2019-02-06                                             Amazon
# 330 2019-02-06  Transfer to Bank of America Cash Rewards World...
# 331 2019-02-06                                            GrubHub
# 332 2019-02-05                                       Cornell Tech
# 333 2019-02-05                                           Interest
# 334 2019-02-04                                Amazon web services
# 335 2019-02-01                                            Netflix
# 336 2019-02-01                                            Netflix
# 337 2019-01-31                                         Soylent Ca
# 338 2019-01-30                            Foreign Transaction Fee
# 339 2019-01-30                                            Expedia
# 340 2019-01-29                                Federal Withholding
# 341 2019-01-29                                    Interest Earned
# 342 2019-01-22  Transfer to Bank of America Cash Rewards World...
# 343 2019-01-19                      Transfer from Rewards Savings
# 344 2019-01-14                                  17life.com Taipei
# 345 2019-01-14                            Foreign Transaction Fee
# 346 2019-01-14                                Wall Street Journal
# 347 2019-01-12                                             Amazon
# 348 2019-01-11                                            Spotify
# 349 2019-01-03                                Amazon web services
# 350 2019-01-02                                            Netflix
# 351 2019-01-02                                            Netflix
#
#                                   original_description   amount  \
# 0                                    PAYPAL *WISALKHAN   439.98
# 1                                 MTA*METROCARD MACHIN    26.25
# 2                                                TIDAL     9.99
# 3                                 GRIFFIS FACULTY CLUB     5.49
# 4                BILL PAY HOLD ONLINE PAYMENT ON 04/11   539.18
# 5    POS DEBIT                SpotifyUSA           ...     4.99
# 6    ORIG CO NAME:DESERVE INC      COENTRY DESCR:PA...    69.34
# 7     POS DEBIT                MGP*Chrono24 GmbH TC 12  3624.00
# 8    DESERVE INC      PAYMENT    384591          WE...    45.90
# 9             ROBINHOOD        FundsPPD ID: 1464364776  1079.11
# 10            ROBINHOOD        FundsPPD ID: 1464364776   335.55
# 11            ROBINHOOD        FundsPPD ID: 1464364776  1361.24
# 12            ROBINHOOD        FundsPPD ID: 1464364776   895.30
# 13   Online Transfer from SAV ...0615transaction#: ...  3000.00
# 14   Online Transfer to CHK ...0515 transaction#: 8...  3000.00
# 15                 GRUBHUBWHOLESOMEFACTO 8775851085 NY    17.35
# 16   Online Transfer from SAV ...0615transaction#: ...  3000.00
# 17   Online Transfer to CHK ...0515 transaction#: 8...  3000.00
# 18                    NYC FERRY MOBILE 415-438-8311 NY     2.75
# 19                  GRUBHUBCHINA1KITCHEN 8775851085 NY    10.71
# 20                      GRUBHUBABUMIPOKE 8775851085 NY    38.20
# 21                       9640 AMC ONLINE 8884404262 KS    23.95
# 22               LYFT   *RIDE FRI 9PM LYFT.COM CA04/06    38.40
# 23               LYFT   *RIDE FRI 2PM lyft.com CA04/05    20.74
# 24                    ROMANO'S GRILL LS MCO ORLANDO FL    85.00
# 25                 SOMMERFEST RESTAURA LAKE BUENA VIFL    10.96
# 26                    GERMANY BIERLINE LAKE BUENA VIFL    19.50
# 27                 LIBERTY INN KIOSK 0 LAKE BUENA VIFL    13.25
# 28                 PLAZA DE LOS AMIGOS LAKE BUENA VIFL    43.97
# 29                     DELTA 00673009765875 NORWALK CT   241.30
# ..                                                 ...      ...
# 322                           CORNELL TECH NEW YORK NY     7.00
# 323  GRUBHUBPICCOLOTRATTOR GRUBHUB.COM NY         0...    27.42
# 324                              FUJI EAST NEW YORK NY    30.00
# 325                        GRISTEDES # 512 NEW YORK NY     7.42
# 326                                            PAYMENT   913.88
# 327                           CORNELL TECH NEW YORK NY     9.00
# 328                 AETNA-866-36-VITAL 866-368-4825 TX     7.99
# 329             AMZN MKTP US*MB38S32M2 AMZN.COM/BILLWA    29.79
# 330           Bank of America Credit Card Bill Payment   913.88
# 331  GRUBHUBVIDALISPIZZA GRUBHUB.COMNY           02/06    37.04
# 332                           CORNELL TECH NEW YORK NY     6.97
# 333                                   INTEREST PAYMENT     0.63
# 334  Amazon web services aws.amazon.co WA         0...    21.09
# 335  NETFLIX.COM Amsterdam01/31 TW Dollar  390.00 X...    12.71
# 336  FOREIGN EXCHANGE RATE ADJUSTMENTFEE         01...     0.38
# 337                              SOYLENT 8447695368 CA    37.05
# 338                     FOREIGN TRANSACTION FEE C_FEES    25.33
# 339             EXPEDIA 7408803115163 EXPEDIA.CO.TWESP   844.53
# 340                                Federal Withholding     0.12
# 341                                    Interest Earned     0.50
# 342           Bank of America Credit Card Bill Payment   123.71
# 343                                            PAYMENT   123.71
# 344                                  17Life.com TAIPEI    13.07
# 345                     FOREIGN TRANSACTION FEE C_FEES     0.39
# 346  D J*WALL-ST-JOURNAL 800-568-7625MA          01/13     4.00
# 347             AMZN DIGITAL*MB7SU0AH1 888-802-3080 WA     5.99
# 348                    Spotify USA 646-8375380 NY01/11     4.99
# 349  Amazon web services aws.amazon.co WA         0...    21.09
# 350  FOREIGN EXCHANGE RATE ADJUSTMENTFEE         12...     0.38
# 351  NETFLIX.COM Amsterdam12/31 TW Dollar  390.00 X...    12.75
#
#     transaction_type                category  \
# 0              debit                     NaN
# 1              debit   public transportation
# 2              debit                   music
# 3              debit             restaurants
# 4              debit     credit card payment
# 5              debit                   music
# 6              debit                     NaN
# 7              debit                     NaN
# 8              debit                     NaN
# 9              debit                     NaN
# 10             debit                     NaN
# 11             debit                     NaN
# 12             debit                     NaN
# 13            credit                transfer
# 14             debit                transfer
# 15             debit           food & dining
# 16            credit                transfer
# 17             debit                transfer
# 18             debit   public transportation
# 19             debit           food & dining
# 20             debit           food & dining
# 21             debit           movies & dvds
# 22             debit       rental car & taxi
# 23             debit       rental car & taxi
# 24             debit             restaurants
# 25             debit             restaurants
# 26             debit               groceries
# 27             debit                   hotel
# 28             debit             restaurants
# 29             debit              air travel
# ..               ...                     ...
# 322            debit                     NaN
# 323            debit           food & dining
# 324            debit             restaurants
# 325            debit               groceries
# 326           credit     credit card payment
# 327            debit                     NaN
# 328            debit        health insurance
# 329            debit                shopping
# 330            debit     credit card payment
# 331            debit           food & dining
# 332            debit                     NaN
# 333           credit         interest income
# 334            debit  electronics & software
# 335            debit           movies & dvds
# 336            debit           movies & dvds
# 337            debit               groceries
# 338            debit             service fee
# 339            debit                  travel
# 340            debit             federal tax
# 341           credit         interest income
# 342            debit     credit card payment
# 343           credit     credit card payment
# 344            debit                     NaN
# 345            debit             service fee
# 346            debit  newspapers & magazines
# 347            debit                shopping
# 348            debit                   music
# 349            debit  electronics & software
# 350            debit           movies & dvds
# 351            debit           movies & dvds
#
#                                           account_name  labels  notes
# 0    Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 1    Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 2    Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 3    Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 4                                      Rewards Savings     NaN    NaN
# 5                                        CHASE COLLEGE     NaN    NaN
# 6                                        CHASE COLLEGE     NaN    NaN
# 7                                        CHASE COLLEGE     NaN    NaN
# 8                                        CHASE COLLEGE     NaN    NaN
# 9                                        CHASE COLLEGE     NaN    NaN
# 10                                       CHASE COLLEGE     NaN    NaN
# 11                                       CHASE COLLEGE     NaN    NaN
# 12                                       CHASE COLLEGE     NaN    NaN
# 13                                       CHASE COLLEGE     NaN    NaN
# 14                                       CHASE SAVINGS     NaN    NaN
# 15   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 16                                       CHASE COLLEGE     NaN    NaN
# 17                                       CHASE SAVINGS     NaN    NaN
# 18   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 19   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 20   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 21   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 22                                       CHASE COLLEGE     NaN    NaN
# 23                                       CHASE COLLEGE     NaN    NaN
# 24   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 25   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 26   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 27   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 28   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 29   Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# ..                                                 ...     ...    ...
# 322  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 323                                      CHASE COLLEGE     NaN    NaN
# 324  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 325  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 326  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 327  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 328  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 329  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 330                                    Rewards Savings     NaN    NaN
# 331                                      CHASE COLLEGE     NaN    NaN
# 332  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 333                                      CHASE SAVINGS     NaN    NaN
# 334                                      CHASE COLLEGE     NaN    NaN
# 335                                      CHASE COLLEGE     NaN    NaN
# 336                                      CHASE COLLEGE     NaN    NaN
# 337  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 338  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 339  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 340                                    Rewards Savings     NaN    NaN
# 341                                    Rewards Savings     NaN    NaN
# 342                                    Rewards Savings     NaN    NaN
# 343  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 344  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 345  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 346                                      CHASE COLLEGE     NaN    NaN
# 347  Bank of America Cash Rewards World Mastercard ...     NaN    NaN
# 348                                      CHASE COLLEGE     NaN    NaN
# 349                                      CHASE COLLEGE     NaN    NaN
# 350                                      CHASE COLLEGE     NaN    NaN
# 351                                      CHASE COLLEGE     NaN    NaN
#
# [352 rows x 9 columns]

# %%
trans.iloc[0]['date']
# Out:
# Timestamp('2019-04-11 00:00:00')

# %%
coffee_sum
# Out:
# 1159.72

# %%
coffee_brk
# Out:
# [3000.0]

# %%
trans.iloc[135]
# Out:
# date                                         2019-03-19 00:00:00
# description                                  Robinhood Funds Ppd
# original_description    ROBINHOOD        FundsPPD ID: 1464364776
# amount                                                      3000
# transaction_type                                           debit
# category                                         mortgage & rent
# account_name                                       CHASE COLLEGE
# labels                                                       NaN
# notes                                                        NaN
# Name: 135, dtype: object
